# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from time import time
import datetime

# %% [markdown]
# ## Load Dataset

# %%
cifar = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar.load_data()
x_train, x_test = tf.image.per_image_standardization(x_train), tf.image.per_image_standardization(x_test) 
x_train, x_test = tf.image.resize(x_train, (227, 227)), tf.image.resize(x_test, (227, 227))

# %%
tf.image.resize(x_train, (227, 227))
# Out:
# <tf.Tensor: shape=(50000, 227, 227, 3), dtype=float32, numpy=
# array([[[[0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          ...,
#          [0.5803922 , 0.4862745 , 0.40392157],
#          [0.5803922 , 0.4862745 , 0.40392157],
#          [0.5803922 , 0.4862745 , 0.40392157]],
#
#         [[0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          ...,
#          [0.5803922 , 0.4862745 , 0.40392157],
#          [0.5803922 , 0.4862745 , 0.40392157],
#          [0.5803922 , 0.4862745 , 0.40392157]],
#
#         [[0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          [0.23137255, 0.24313726, 0.24705882],
#          ...,
#          [0.5803922 , 0.4862745 , 0.40392157],
#          [0.5803922 , 0.4862745 , 0.40392157],
# ...
